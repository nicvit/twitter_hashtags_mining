# %% [markdown]
# # Keywords extraction from web pages
#
# We want to extract keywords related to smoking from a series of web documents. The aim of this phase is to extract important words related to the topic that will then be inputed as hashtags in the search through the Twitter API.
#
# It is important to keep in mind that we want to find keywords on different __degrees of parlance__, so we first set the levels and we manually annotate a number of web pages for each. We then go to extract key-words from every document using the best approach  in each case.
#
# Things to do:
# 1. Decide which __registers__ to target
# 2. Manually annotate a series of __web pages for each level__ (around 15 per each)
# 3. __Scrape__ the web pages, parse document and extract key-words (within each level do the following):
#     - save html files from txt list of urls (if pdf coerce t html)
#     - parse html documents and produce txt
#     - apply proper algorithm for keywords extraction (we deal with two main types: long-text and forum-like comments); apply to each level and extract N keywords per level.
#
# Output:
# - A "multi-level-register" well designed list of keywords to retrive on-topic tweets from twitter API (decided to use 3 levels: Frozen (f), Consultative(c), occasional (o))
#
# -------
#
# ## 1. Decide which __registers__ to target
# From Wikipedia:
#
# [Register (sociolinguistics)](https://en.wikipedia.org/wiki/Register_(sociolinguistics))
#
# >In one prominent model, Martin Joos (1961) describes five styles in spoken English:
#
# >__Frozen__: Also referred to as static register. Printed unchanging language, such as Biblical quotations, often contains archaisms. Examples are the Pledge of Allegiance of the United States of America and other "static" vocalizations that are recited in a ritualistic monotone. The wording is exactly the same every time it is spoken.
# __Formal__: One-way participation; no interruption; technical vocabulary or exact definitions are important; includes presentations or introductions between strangers.
# __Consultative__: Two-way participation; background information is provided – prior knowledge is not assumed. "Back-channel behavior" such as "uh huh", "I see", etc. is common. Interruptions are allowed. Examples include teacher/student, doctor/patient, expert/apprentice, etc.
# __Casual__: In-group friends and acquaintances; no background information provided; ellipsis and slang common; interruptions common. This is common among friends in a social setting.
# __Intimate__: Non-public; intonation more important than wording or grammar; private vocabulary. Also includes non-verbal messages. This is most common among family members and close friends.>
#
# --------
#
# ## 2. Manually annotate a series of __web pages for each level__ (20 pages per level)
#
# __Frozen__:
# 1. [https://www.gov.uk/government/publications/new-rules-about-tobacco-e-cigarettes-and-smoking-1-october-2015/new-rules-about-tobacco-e-cigarettes-and-smoking-1-october-2015]
# 2. [https://www.ontario.ca/page/smoke-free-ontario]
# 3. [http://betobaccofree.hhs.gov/laws/]
# 4. [https://malegislature.gov/Laws/GeneralLaws/PartIV/TitleI/Chapter270/Section22]
# 5. [https://www.gov.uk/government/news/public-health-england-publishes-independent-evidence-papers-on-e-cigarettes]
# 6. [https://www.gov.uk/government/news/press-briefing-afternoon-3-april-2014]
# 7. [https://www.gov.uk/government/news/government-response-to-tobacco-standardised-packaging-review]
# 8. [https://www.gov.uk/government/news/smokers-twice-as-likely-to-die-of-stroke]
# 9. [https://www.gov.uk/government/news/lung-cancer-rates-rising-amongst-women-yet-falling-in-men]
# 10. [https://www.gov.uk/government/news/new-tool-models-youth-smoking-variation-across-england]
# 11. [https://www.gov.uk/government/news/government-backs-standardised-packaging-of-tobacco]
# 12. [https://www.gov.uk/government/news/protecting-children-from-secondhand-smoke-and-nicotine-addiction]
# 13. [https://www.gov.uk/government/publications/tobacco-products-and-e-cigarette-cross-border-sales-registration]
# 14. [https://www.gov.uk/government/news/chronic-smoking-related-lung-disease-blights-over-1-million-lives-in-england]
# 15. [https://www.gov.uk/government/news/e-cigarettes-an-emerging-public-health-consensus]
# 16. [https://www.gov.uk/government/publications/2010-to-2015-government-policy-smoking/2010-to-2015-government-policy-smoking]
# 17. [https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/416442/Living_Well_for_Longer_-_One_year_on__March_2015_.pdf]
# 18. [https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/403489/Consultation_summary.pdf]
# 29. [https://www.gov.uk/government/news/smoking-in-cars-is-now-illegal]
# 20. [http://www2.warwick.ac.uk/services/healthsafetywellbeing/guidance/smokingpolicy/]
#
#
# __Consultative__:
#
# _Trends_
# 1. [http://www.tobaccoinaustralia.org.au/chapter-2-consumption/2-0-introduction]
# 2. [http://www.hhs.gov/ash/oah/adolescent-health-topics/substance-abuse/tobacco/trends.html]
# 3. [http://bmcpublichealth.biomedcentral.com/articles/10.1186/1471-2458-12-958]
#
# _Health_
# 4. [http://www.tobaccoinaustralia.org.au/chapter-3-health-effects/3-0-background]
# 5. [https://www.nhs.uk/smokefree/why-quit/smoking-health-problems]
# 6. [http://www.quitshisha.com/effects-of-shisha.html]
# 7. [https://consumer.healthday.com/kids-health-information-23/adolescents-and-teen-health-news-719/illicit-substance-use-more-common-in-brazilian-teens-with-mental-illness-713518.html]
#
# _Prevention_
# 8. [http://www.tobaccoinaustralia.org.au/chapter-5-uptake/5-1-introduction]
# 9. [http://www.surgeongeneral.gov/library/reports/preventing-youth-tobacco-use/factsheet.html]
# 10. [https://consumer.healthday.com/public-health-information-30/marijuana-news-759/medical-marijuana-appears-to-reduce-need-for-other-meds-study-712657.html]
#
# _Addiction_
# 11. [http://www.tobaccoinaustralia.org.au/chapter-6-addiction/6-0introduction]
# 12. [http://healthliteracy.worlded.org/docs/tobacco/Unit3/1why_people_smoke.html]
# 13. [https://www.drugabuse.gov/publications/research-reports/tobacco/nicotine-addictive]
#
# _Industry_
# 14. [http://www.tobaccoinaustralia.org.au/chapter-10-tobacco-industry/10-0-introduction]
# 15. [http://www.economist.com/news/business/21594984-big-tobacco-firms-are-maintaining-their-poise-quietly-wheezing-running-out-puff]
# 16. [http://www.reuters.com/article/us-ecigarettes-regulations-specialreport-idUSKBN0MJ0GN20150323]
# 17. [http://news.stanford.edu/news/2011/december/tobacco-industry-proctor-121211.html]
#
# _Advertising_
# 18. [http://www.tobaccoinaustralia.org.au/chapter-11-advertising/11-0-background]
# 19. [https://en.wikipedia.org/wiki/Tobacco_advertising]
# 20. [http://www.dailymail.co.uk/health/article-2889691/Graphic-anti-smoking-advert-featuring-father-lighting-roll-rotting-flesh-unveiled-report-aims-highlight-lesser-known-consequences-habit.html]
#
# __Occasional__:
# 1. [http://www.cigreviews.com/forums/general-smokers-discussion/1-whats-price-cigarettes-your-state.html]
# 2. [http://www.cigreviews.com/forums/general-smokers-discussion/163-what-made-you-start.html]
# 3. [http://www.cigreviews.com/forums/general-smokers-discussion/2095-how-many-cigarettes-do-you-smoke-per-day.html]
# 4. [http://www.cigreviews.com/forums/electronic-cigarettes-e-cigarettes/2370-e-cigs-suck.html]
# 5. [http://www.cigreviews.com/forums/electronic-cigarettes-e-cigarettes/5267-every-option-vaping-devices.html]
# 6. [http://www.cigreviews.com/forums/electronic-cigarettes-e-cigarettes/3591-mt-baker-vapor-usa-made-e-juice-starter-kits-fast-shipping-friendly-service.html]
# 7. [http://www.cigreviews.com/forums/electronic-cigarettes-e-cigarettes/2207-what-electronic-cigarettes-like-use.html]
# 8. [http://www.cigreviews.com/forums/ryo-roll-your-own-cigarettes/4701-saturdat-night-what-ya-drinkin-smokin-thread.html]
# 9. [http://www.cigreviews.com/forums/ryo-roll-your-own-cigarettes/5128-new-guy.html]
# 10. [http://www.cigreviews.com/forums/smokers-rights/104-who-truly-selfish-smokers-anti-smokers.html]
# 11. [http://www.cigreviews.com/forums/snus-tobacco/731-best-snus-tobacco.html]
# 12. [http://www.cigreviews.com/forums/marlboro-cigarettes/345-5-80-pack-marlboros-today-omg.html]
# 13. [https://drugs-forum.com/forum/showthread.php?t=225934]
# 14. [https://drugs-forum.com/forum/showthread.php?t=202451]
# 15. [https://drugs-forum.com/forum/showthread.php?t=247493]
# 16. [https://drugs-forum.com/forum/showthread.php?t=184485]
# 17. [https://drugs-forum.com/forum/showthread.php?t=264914]
# 18. [https://drugs-forum.com/forum/showthread.php?t=193267]
# 19. [https://drugs-forum.com/forum/showthread.php?t=170114]
# 20. [https://drugs-forum.com/forum/showthread.php?t=220659]

# %% [markdown]
# -------
#
# ## 3. __Scrape__ the web pages, parse document and extract key-words
#
# ##### save html files from txt list of urls (if pdf coerce t html)
# The .txt document containing the list of url it is in ~/develop/data/web_pages_mining/url_list_fORcORo.txt.

# %%
# script to go through the list of urls .txt and save .html fles

# %% [markdown]
# ##### parse html documents and produce txt

# %%
# script parse .html files and produce .txt files

# %% [markdown]
# ##### apply proper algorithm for keywords extraction
#
# Possible algorithms:
#
# - RAKE (Rapid Automatic Keyword Extraction)
#     * Web resources
#         * [NLP keyword extraction tutorial with RAKE](https://www.airpair.com/nlp/keyword-extraction-tutorial#3-keyword-extraction-with-python-using-rake)
#         * [Keyword Extraction with RAKE](http://libmunin.readthedocs.io/en/latest/api/stopwords.html)
#     * Papers
#         * [Human-competitive automatic topic indexing](https://78462f86-a-c00374d1-s-sites.googlegroups.com/a/medelyan.com/www/files/phd2009.pdf?attachauth=ANoY7cqdnIMLLJegr1KixbbLLHUNxirRiA7GUOL9RqdSQ-9JlOjpF5Tix4Jw7eAkg22NxAJcZ-tFiFzfd-YmvbJwNka41vdx8aBdwBPAK8jCZNGZLL6VK8ljNGIMCNZWd6gcHAd29FxGiZjKX-B6bBIndWWV0BQXsgV9-q-sTzqrz9RI2mTeN_0vx9bqqL_G22J2Njdz7Qj8vrsTmlIfuLpMtat4rJXVvw%3D%3D&attredirects=0)
#         * [Automatic keyword extraction from individual documents](http://media.wiley.com/product_data/excerpt/22/04707498/0470749822.pdf)
#
# - TextRank (graph based)
#     * Web resources
#         * [Python Implementation of TextRank (Github Repo)](http://www.davidadamojr.com/textrank-implementation-in-python-github-repo/)
#     * Papers
#         * [Mihalcea and Tarau](https://web.eecs.umich.edu/~mihalcea/papers/mihalcea.emnlp04.pdf)
#         * [Rose et al.](http://media.wiley.com/product_data/excerpt/22/04707498/0470749822.pdf)
#
# - Features generation and logistic regression
#     * Web resources
#         * [Keyword finder](https://people.csail.mit.edu/lavanya/keywordfinder)
#     * Papers
#         * [Jean-Louis](http://www.cys.cic.ipn.mx/ojs/index.php/CyS/article/viewFile/1523/1506)
#
#
# __Note__: The TextRank algorithm consider the text legnt of the document giving it a weight; since we are considering different registers the RAKE could be better. [Edit] TextRank focus on sentences, best decision is the last one trained in each register.
#
# [^a-zA-Z0-9_+/-] # words stripper
# (?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s # phrases stripper   # try to change in rake
#
# --------------
#
# _ROUGH_: use RAKE on the entire register corpus.
# _FINAL DECISION_: use the algorithm "Features generation and logistic regression" training it on the corpus for each register (f, c, o).

# %%
# script that use rake to extract keywords from the web pages corpus of 3 registers (extract n keywords from each)

# packages
import os
import re
import rake
import operator
import io


# get paths to files
baseFolder = '/Users/nicolavitale/Desktop/twitter_data_analysis/develop/data/web_pages_mining/txt/all'
for rSDir, rDirs, rFiles in os.walk(baseFolder):
    rFiles = [f for f in rFiles if not f[0] == '.']
    rDirs[:] = [d for d in rDirs if not d[0] == '.']
    paths = []
    wps_names_list = []
    for txt in rFiles:
        paths.append(os.path.join(baseFolder, txt))
        txt = re.sub(r'.txt', '', txt, flags=re.DOTALL)
        wps_names_list.append(txt)
        

# open each file, append on list
parsed_wps_list = []
for f in paths:  
    with open(f, 'r') as myfile:
        myfile = myfile.read()
        parsed_wps_list.append(myfile)

f_list = parsed_wps_list[0:20]
c_list = parsed_wps_list[20:40]
o_list = parsed_wps_list[40:60]

# [^a-zA-Z0-9_+/-] # words stripper
# (?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s # phrases stripper   # try to change in rake

def key_unigrams(register_text, c, t):
    
    stoppath = "/Users/nicolavitale/Desktop/twitter_data_analysis/develop/data/SmartStoplist.txt"
    rake_object_register = rake.Rake(stoppath, c, 1, t) # Each word has at least n characters, Each phrase has at most n words, Each keyword appears in the text at least n times
    unigram_tuples = rake_object_register.run(register_text) # list of tuples (string is in position 0)
    
    unigrams = [str(t[0]) for t in unigram_tuples]
        
    return unigrams # list of unigrams
    
    
def key_ngrams(register_text, c, t):
    
    stoppath = "/Users/nicolavitale/Desktop/twitter_data_analysis/develop/data/SmartStoplist.txt"
    rake_object_register = rake.Rake(stoppath, c, 5, t) # Each word has at least n characters, Each phrase has at most n words, Each keyword appears in the text at least n times
    ngram_tuples = rake_object_register.run(register_text) # list of tuples (string is in position 0)
    
    ngrams = [str(t[0]) for t in ngram_tuples if len(str(t[0]).split())>1]
    
    return ngrams # list of ngrams
    
    
# takes the list of register keywords and return the query; there will be "#tobacco" + "tobacco #control #act"
def query_list_register(unigrams, ngrams): # list list
    
    hashtags = ["#" + unigram for unigram in unigrams]

    keys_hashtags = []
    keys_hashtags = list(ngrams)
    for idx_ngram, ngram in enumerate(ngrams):
        
        grams_list = ngram.split()
        
        k_h_list = [] # must include the ngram again with inverted hashtags! ex: unigram: #smoker --> ngram: smoker #lobby
        k_h_list = list(grams_list)
        for idx_word, word in enumerate(grams_list):
            if word not in unigrams:
                k_h_list[idx_word] = "#" + word
                            
        keys_hashtags[idx_ngram] = str(" ".join(k_h_list))
        
    queries = hashtags + keys_hashtags
    
    return queries

# f_queries = query_list_register(key_unigrams(f_list[1], 2, 5), key_ngrams(f_list[1], 2, 5))
# print f_queries

f_queries_all = [key_ngrams(txt, 4, 5) for txt in f_list] # Each word has at least n characters, Each keyword appears in the text at least n times
# for txt in f_list:
#     f_unigrams = key_unigrams(txt, 2, 10)
#     f_ngrams = key_ngrams(txt, 2, 5)
#     f_queries = query_list_register(f_unigrams, f_ngrams)
#     f_queries_all = f_queries_all + f_queries
    
c_queries_all = [key_ngrams(txt, 4, 3) for txt in o_list]
# for txt in c_list:
#     c_unigrams = key_unigrams(txt, 2, 5)
#     c_ngrams = key_ngrams(txt, 2, 5)
#     c_queries = query_list_register(c_unigrams, c_ngrams)
#     c_queries_all = c_queries_all + c_queries

o_queries_all = [key_ngrams(txt, 2, 2) for txt in o_list]
# for txt in o_list:
#     o_unigrams = key_unigrams(txt, 2, 5)
#     o_ngrams = key_ngrams(txt, 2, 5)
#     o_queries = query_list_register(o_unigrams, o_ngrams)
#     o_queries_all = o_queries_all + o_queries
    


print "FROZEN language keywords"
print"----------------------------------------------------------------------------------------------------------------"
print
print list(f_queries_all)
print 
print "CONSULTATIVE language keywords"
print"----------------------------------------------------------------------------------------------------------------"
print
print list(c_queries_all)
print
print "CONSULTATIVE language keywords"
print"----------------------------------------------------------------------------------------------------------------"
print
print list(o_queries_all)
print 
print"----------------------------------------------------------------------------------------------------------------"
print
# Out:
# FROZEN language keywords
# ----------------------------------------------------------------------------------------------------------------
#
# ...

# %%
import pandas as pd
import numpy as np

manually_selected_first = ["tobacco", "tobacco products", "marijuana", "medical marijuana", "smoke", "tobacco advertising", "tobacco control", "cigarette companies", "tobacco companies", "tobacco industry", "cigarette packs", "cigarette advertising", "cigarette brand", "tobacco marketing", "tobacco sponsorship", "tobacco advertisements", "smoking", "smokeless", "smokeless tobacco", "smoking prevalence", "shisha", "smoker", "cigarette tax", "cancer", "cancer society", "health", "public health", "health care", "smoking ban", "smoker lobby", "smoking habit", "smokers", "marlboro", "snus", "heroin", "hookah", "oral tobacco", "quit smoking", "bronchial", "asthmatics", "asthmatics smoking", "cigs", "vaping", "vaping devices", "electronic cigarettes", "cheapest cigarette", "reduce smoking rates", "tobacco illegal", "pipe", "antismoking", "cigarette sales", "smoke anymore", "reducing smoking", "tobacco smoke", "smoke worry", "diabetes risk", "heart attack", "drug", "kretek", "hooka", "stay clean", "smoking crystal", "menthol", "toke", "acid trip", "inhalation", "pipe smoking", "inhale", "sputum", "asthma", "bronchial", "ecig", "eliquids", "vaporizer"]

manually_selected_second = ["tobacco products", "medical marijuana", "smoke", "tobacco advertising", "tobacco control", "cigarette companies", "tobacco companies", "tobacco industry", "cigarette packs", "cigarette advertising", "cigarette brand", "tobacco marketing", "tobacco sponsorship", "tobacco advertisements", "smoking", "smokeless", "smoking prevalence", "shisha", "smoker", "cigarette tax", "lung cancer", "cancer society", "public health", "health care", "smoking ban", "smoker lobby", "smoking habit", "marlboro", "snus", "heroin", "hookah", "oral tobacco", "quit smoking", "cig", "vaping", "electronic cigarettes", "cheapest cigarette", "reduce smoking rates", "tobacco illegal", "antismoking", "cigarette sales", "smoke anymore", "reducing smoking", "smoke worry", "diabetes risk", "heart attack", "drug", "kretek", "hooka", "stay clean", "smoking crystal", "menthol", "toke", "acid trip", "inhalation", "inhale", "sputum", "asthma", "bronchial", "ecig", "eliquids", "vaporizer"]

manually_selected_third = ["tobacco product", "medical marijuana", "tobacco advert", "tobacco control", "cigarette companies", "tobacco companies", "tobacco industry", "cigarette pack", "cigarette advert", "cigarette brand", "tobacco market", "smoking", "smokeless", "smoking prevalence", "shisha", "smoker", "cigarette tax", "lung cancer", "cancer society", "public health", "health care", "smoking ban", "smoker lobby", "smoking habit", "marlboro", "snus", "heroin", "hookah", "oral tobacco", "quit smoking", "cig", "vaping", "electronic cigarette", "cheapest cigarette", "reduce smoking", "tobacco illegal", "antismoking", "cigarette sale", "smoke anymore", "reducing smoking", "smoke worry", "diabetes risk", "heart attack", "drug", "kretek", "hooka", "stay clean", "smoking crystal", "menthol", "toke", "acid trip", "inhalation", "inhale", "sputum", "asthma", "bronchial", "ecig", "eliquid", "vaporizer"]
# ensure that the list is balanced (ex.: not too many key n-grams related to tobacco should be the same as other main topics)
# last selection; tried to be as balanced as possible
# selected 5 per category in categoiries: DRUGS, SMOKE, CIGARETTE, ECIGARETTE, TOBACCO
manually_selected_last = ['drug', 'heroin', 'marijuana', 'stay clean', 'nicotine', 'quit smoking', 'smoke anymore', 'smokeless', 'smoker', 'smoking habit', 'cig', 'cigarette advert', 'cigarette brand', 'cigarette pack', 'malboro', 'ecig', 'electronic cigarette', 'vaping', 'vaporizer', 'hookah', 'shisha', 'tobacco control', 'tobacco illegal', 'tobacco industry', 'tobacco market', 'tobacco product']
manually_selected_last = pd.Series(sorted(manually_selected_last))
manually_selected_last
# Out:
# 0                      cig
# 1         cigarette advert
# 2          cigarette brand
# 3           cigarette pack
# 4                     drug
# 5                     ecig
# 6     electronic cigarette
# 7                   heroin
# 8                   hookah
# 9                  malboro
# 10               marijuana
# 11                nicotine
# 12            quit smoking
# 13                  shisha
# 14           smoke anymore
# 15               smokeless
# 16                  smoker
# 17           smoking habit
# 18              stay clean
# 19         tobacco control
# 20         tobacco illegal
# 21        tobacco industry
# 22          tobacco market
# 23         tobacco product
# 24                  vaping
# 25               vaporizer
# dtype: object
