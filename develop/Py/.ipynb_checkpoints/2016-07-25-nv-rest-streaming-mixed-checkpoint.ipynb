# %% [markdown]
# ## Notebook to develop a Twitter _searchAPI_ collector
#
# functions to save to and load from mongo
# functions tho exeute the queries to the API
#
# METHODS WE WANT TO USE IN PROJECT:
#
# - [GET search/tweets](https://dev.twitter.com/rest/reference/get/search/tweets)
# - [GET statuses/user_timeline](https://dev.twitter.com/rest/reference/get/statuses/user_timeline)

# %% [markdown]
# ## Notebook to develop a Twitter _streamingAPI_ collector
#
# METHODS WE WANT TO USE IN PROJECT:
# - [GET statuses/sample](https://dev.twitter.com/streaming/reference/get/statuses/sample)

# %% [markdown]
# ---

# %% [markdown]
# # Mixed use to retrive data faster
# How do we find keywords related tweets faster?
#
# We use a mix of the SEARCH and STREAMING APIs:
# 1. Retrive as meany tweets as possible in the past (past week) using the SEARCH API
# 2. Continue the search using the STREAMING API until the number of desired tweets associated with the keyword is retrived

# %%
import twitter
import urllib2
import pymongo
import sys
import json
import re
import os

# %%
# manually_selected_last = ['drug', 'heroin', 'marijuana', 'nicotine', 'quit smoking', 'smoke anymore', 'smokeless', 'smoker', 'smoking habit', 'cig', 'cigarette advert', 'cigarette brand', 'cigarette pack', 'malboro', 'ecig', 'electronic cigarette', 'vaping', 'vaporizer', 'hookah', 'shisha', 'tobacco control', 'tobacco illegal', 'tobacco industry', 'tobacco market', 'tobacco product']
# only unigram
manually_selected_last = ['drug', 'marijuana', 'nicotine', 'tobacco', 'smoking', 'smoke', 'smoker', 'cig', 'cigarette', 'ecig', 'vaping', 'vaporizer', 'shisha']
print len(manually_selected_last)
# MANUALLY INPUT EACH KEY-WORD

# Use the SEARCHER to gather as many tweets as possible in the past
# Use the STREAMER to arrive at 2000 tweets per keyword
# Out:
# 13

# %%
# SEARCHER
# credentials: "coffee1"
########################################################

def oauth_login():

    CONSUMER_KEY = 'cOExq4T3uYu9CbdqmMUukGVqV'
    CONSUMER_SECRET = 'u9WCLUaWCLyILtHNGDAMmowxoQseQenyW0avsXhuz8NkPgLHMv'
    OAUTH_TOKEN = '4061210361-uHZhAHfTim8nnyyCWeZXMfLbypbq3Z2jgGcTmhu'
    OAUTH_TOKEN_SECRET = 'nbC4YzeS7vBBBcOWyYgr4msKdLgfRznFQAon1ji2lJn2F'
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
     CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)

    print >> sys.stderr, 'Succesfully connected to TwitterAPI ... ... '

    return twitter_api


def twitter_search(twitter_api, q, max_results=2000, **kw):
    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    for _ in range(179): # 180 max number of query we can issue in 15 minutes (1 it is outside the loop)
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError, e: # No more results when next_results doesn't exist
            print "Length of statuses", len(statuses) 
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)

        statuses.extend(search_results['statuses'])
        
        if len(statuses) > max_results: 
            break
        
    return statuses


def save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw):
    try:
        mongo_db_coll.insert_one(data)
        print "Saving tweet"
    except:
        print "Error message from MongoDB, skipping tweet and continuing."
        




if __name__ == "__main__":

    # search keyword ONE by ONE, gather 2000 tweets for each


    ##############################################
    ##############################################
    #   Stream parameters: just modify these, do NOT touch the rest
    ##############################################
    ##############################################

    client = pymongo.MongoClient()
    db = client.stream   # DATABASE_NAME
    collection = db.get_hashtags     # COLLECTION_NAME

    # search keyword ONE by ONE, gather 2000 tweets for each
    keyword = 'shisha'

    TAGS = keyword  
    TAGS_LIST = [keyword]

    ##############################################
    ##############################################
    ##############################################

    twitter_api = oauth_login()
    q = keyword
    results = twitter_search(twitter_api, q, lang='en')

    for tweet_doc in results:

        try:
            # 2 small modificatio to the tweet as it is gathered from API

            # 1. Add the tags of the search, to know from which search query the document has been obtained
            tweet_doc['keyword'] = TAGS_LIST  

            # 2. Substitue the defoult _id assigned by Mongo with the tweet id to prevent the same tweet to be inserted more than once
            tweet_doc['_id'] = tweet_doc["id"]
            del tweet_doc['id']

            save_to_mongo(tweet_doc, db, collection)

            print "\n %s \n" % tweet_doc['text']

            documents_in_collection = collection.find({"keyword": keyword}).count()

            if documents_in_collection >= 2000:

                print "Stremed 2000 tweets associated with keyword: \"%s\"" % keyword
                break

        except KeyError:
            print "KeyError, skipping tweet and continuing."
            continue
# Out:
# Succesfully connected to TwitterAPI ... ...
# Length of statuses 79
# Saving tweet
#
#  me 15 mins ago: in my pjs   chillin   watching 80's movies
# me now: waiting for friends   abt to head to a shisha place    in actual pants
#
# Saving tweet
#
#  anyone want a tall 3 hosed hookah for $30? everything included, coals, shisha etc.
#
# Saving tweet
#
#  @Hashbul masha Allah brotha, we dont need shisha to have fun
#
# Saving tweet
#
#  RT @ShishaCyprus: Enjoy a Luxurious Glass Shisha here at :
# Marina Beach Bar by Carob Mill Restaurants
#
# Serving from 12:00pm -... https://t…
#
# Saving tweet
#
#  @Jesrene16 I haven't shisha 2 months weyh
#
# Saving tweet
#
#  YAY SHISHA https://t.co/RHpmqRuIvN
#
# Saving tweet
#
#  @kaptenobviously no shisha no party 😝😝😝😝
#
# Saving tweet
#
#  Enjoy a Luxurious Glass Shisha here at :
# Marina Beach Bar by Carob Mill Restaurants
#
# Serving from 12:00pm -... https://t.co/AYDC7N3r3k
#
# Saving tweet
#
#  ALL IS WELL 😔
#
# Saving tweet
#
#  I'm at Al Fakheer Shisha Lounge in İstanbul https://t.co/vpj3mA6HV4
#
# Saving tweet
#
#  RT @wasAbuKhattab: An hour of smoking argile or shisha is equivalent to 200 cigarettes. Smoking shisha is a major sin and is killing you!
#
# Saving tweet
#
#  I'm at Al Fakheer Shisha Lounge in İstanbul https://t.co/XptjdVLIVB
#
# Saving tweet
#
#  With Hartanto, Karen, and 4 others at Sahara - Authentic Shisha Cafe And Food — https://t.co/WW8REMWXgY
#
# Saving tweet
#
#  Another Day, Another Hookah. I https://t.co/odMUGWzYZu #SHISHA https://t.co/1qm0ELC0NU
#
# Saving tweet
#
#  All these coloured people shisha jokes have mandem like https://t.co/5zyTIYA3IN
#
# Saving tweet
#
#  @HookaConnection I need shisha pot like this https://t.co/hCfkmbSMXp
#
# Saving tweet
#
#  RT @wasAbuKhattab: An hour of smoking argile or shisha is equivalent to 200 cigarettes. Smoking shisha is a major sin and is killing you!
#
# Saving tweet
#
#  shisha https://t.co/1OB84wS2PU
#
# Saving tweet
#
#  RT @Eudaimonalisa: Is it true that in Bradford Uni there's shisha pipes in lectures
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  I'm at Kfp shisha https://t.co/NwZWIDUFWZ
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Try our huge selection of tapas for a light dinner &amp; relax with shisha &amp; mocktails post afterwards. https://t.co/I0NM6hm2iv
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @TobaccoCtrlUg: "Sisha," "Swisha," "Sisa," whatever your pronunciation of Shisha, keep in mind that the law places a complete ban on it.…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @shideboss: Come &amp; see me, Kandman, H Dhami, Jernade &amp; Limelight on Friday 19th Aug at Level Shisha - London
# Postcode: IG6 3UT https://t…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Today is a Shisha kind of day. Tweet us your pictures! #vfestival #bubblelounge #oxygenbar https://t.co/dChtjtWIuH
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Atm 😭🔫 My kind of shisha 🚬😂✌️ https://t.co/quXOswupSV
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Good to be back (@ Snake Shisha D'batavia Cafe in Bukit Gambir, Penang) https://t.co/CzR4DS3QB5
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Living the Hookah Lifestyle! I https://t.co/odMUGWzYZu #SHISHA https://t.co/89TiD60ACm
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @Kirmataqaana can i just say that having a co-codamol tablet during a shisha session = the best high
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  I'm at Dragon Shisha in Gelugor, Penang https://t.co/VfNnriGoe3
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  I'm at Salsabila Shisha Lounge in Johor Bahru, Johor https://t.co/x3dUJ7Cndf
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  VIP this weekend? Do it in style with an E-Shisha! Contact us now to book on 01923 239 848 #WhatsYourFlava https://t.co/1gR97nS5B7
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  pari and i are out celebrating her new internship with shisha and Man Is It A Time To Celebrate
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Annonces #emploi #cdi #cdd par ici ! https://t.co/F8SP4AuOcl - top stories by @Shisha_Lou, @J_ck3113, @CedricBonnet
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Tonight - It's The "Shisha Summer Special" at Club K Hounslow.
#
# Featuring 6 DJs - FREE ENTRY On Guestlist Before... https://t.co/X27wOetMYX
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  With Bubuhan JaKaltim at Aladdin Shisha Cafe — https://t.co/REommaRClM
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @MsGenevieve_: Even smoke (shisha) but ngl, only around two glasses. She barely drinks herself so she's always been funny. https://t.co/…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Even smoke (shisha) but ngl, only around two glasses. She barely drinks herself so she's always been funny. https://t.co/SpoNAtYdTv
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @TheOnlyGuru @DaniBenDover indeed, if ever in Raqqa i will buy him Shisha for such strong seed 👍
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  ngapain? (at Platters Pizza, Grill, &amp; Shisha) — https://t.co/Ug6QP3AyDk
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Shisha na this
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  An hour of smoking argile or shisha is equivalent to 200 cigarettes. Smoking shisha is a major sin and is killing you!
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  EN DIRECTO en #Periscope: shisha time https://t.co/ZXhhajra6b
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @kxvitrxx wokay. Shisha manoi?
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  What's up with Free Shisha on Ladies' Night? This is a conspiracy done by men to damage the health of women and make them go extinct.
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  🙈 (with Jun, Amel Santoso, and 2 others at Sphinx - Shisha Lounge &amp; Bar) [pic] — https://t.co/NCatLFJvg4
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Shisha Phunnel bowls are now available message me for prices
#
# @hookahaddictig  #chicha #hookah… https://t.co/UpImjX4SJS
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @er_ror102 shisha with fumi?
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Ya pombe na shisha https://t.co/m1DkDOB9vJ
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  EN DIRECTO en #Periscope: shisha time https://t.co/srMxJLp2bN
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Can you handle your own Luxury AK47 Hookah? I https://t.co/odMUGWzYZu #SHISHA https://t.co/YP9iH22vOV
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Smoking Shisha and Beer? Not a good thing i have tried it before
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  GET YOUR BOTTLES READY!!!!! #SHOWTIME 2MRW IYAH 👉 SHISHA, TUG OF… https://t.co/6mEAXVVri0
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  DUIs are given all the time, people die because of drunks, accidents happen but alcohol is still legal and shisha tobacco is being banned 😐
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @DawnSunrise1 *passes Shisha pipe*
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  People with alcohol in their system do so much damage to others yet they're banning shisha .. Please explain how that makes sense?
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  I am a shisha weakling
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @BarracudaLDN: Try a flavored Shisha at our bar #BarracudaLDN #londonislovinit https://t.co/2Rp664vBfN
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Dschinni Hookah 😏💨🤘🏽 | Please Follow @hookahblog_ 👆👈 #hookahblog #love #water #shisha… https://t.co/VrcINcmCUL
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Smoke with us in Style! I https://t.co/odMUGWzYZu #SHISHA https://t.co/nXTWOpDs4z
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @ClubKHounslow: This Weekend At Club K Hounslow:
#
# Tonight - Shisha Summer Special
#
# Saturday - Carnival Warm Up: Soca Special... https://…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Cloud Chaser! I https://t.co/hzM1qRLk4e #SHISHA https://t.co/6bImuVLEpO
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  TGIF take a behind the scenes journey with us as we prep all the little models for the annual Bronx kids fashion... https://t.co/D1FQZe3gOX
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  TGIF take a behind the scenes journey with us as we prep all the little models for the annual… https://t.co/afmorQDOAI
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Friday Soccer - Premier: Shisha beat Aces and Eights (10 - 4) https://t.co/xOpMDEeO0d
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @David_Mcc_3: i got a C D D at a-level and now smoke shisha pipes on curry mile.
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @lunarnomad: shisha outdoors on summer nights &gt;&gt;&gt;
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  No caption...... #AirinMelbourne #shishanight #shisha @ Shisha nights https://t.co/sszOiBBV2D
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  @19960422net_ later when we go shisha
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @shideboss: Come &amp; see me, Kandman, H Dhami, Jernade &amp; Limelight on Friday 19th Aug at Level Shisha - London
# Postcode: IG6 3UT https://t…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Colonial #hookah #smoking #shisha https://t.co/4hm9qhHaxT
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Hose for Big Glass Hookah  - Black and Red 1.5M Hose
# GET IT NOW
# ????FREE WORLDWIDE SHIPPING! ????
# ????Sh ... https://t.co/hpqcsoeoyG
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @northpolegwich: Dj's, Shisha, Fine Dining, Pub Dining, Cocktails, Birthdays, Table Service all till 3am 2nite :))) https://t.co/6zzDUlU…
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Have you visited our Shisha terrace? If not than we are waiting for you) https://t.co/LeSS3oOPBn
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Dj's, Shisha, Fine Dining, Pub Dining, Cocktails, Birthdays, Table Service all till 3am 2nite :))) https://t.co/6zzDUlU9UC
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Another Day, Another Hookah. I https://t.co/hzM1qRLk4e #SHISHA https://t.co/Ddy9rBrElM
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  RT @machedamike: Need me some nice shisha Mint. @jamalldaviss uko wapi? Arosto imezidi lol. https://t.co/MUjMCLi0ys
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  All I need is Suya,Shisha and Henny 🙄
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  SOAS shisha lounge
# -___-
#
# Error message from MongoDB, skipping tweet and continuing.
#
#  Who like it ?
#
# #hookahsmoke #hookahplace #hookahsession #shisha #shishatime https://t.co/Xo2XOohykI

# %%
# STREAMER
# credentials: "searcher_nv_0"
########################################################

def oauth_login():

    CONSUMER_KEY = 'FqWhSxd57N9zgn3sr2Jm1cUYg'
    CONSUMER_SECRET = 'LpRHxDlWsGp7uuwDrpouVcOrL6dTsx0qPccKxBXbvlENSyRaHw'
    OAUTH_TOKEN = '4061210361-mh8Hn8pvOabKNfj2dohmk7gBknzWQsARAo2A2lk'
    OAUTH_TOKEN_SECRET = 'XHfTHWN3T6oqgFKTfo4fA2WylPxzi44QDNYdoRDsE868c'
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
     CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)

    print >> sys.stderr, 'Succesfully connected to TwitterAPI ... ... '

    return twitter_api



def save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw):
    try:
        mongo_db_coll.insert_one(data)
        # print "Saving tweet"
    except:
        print "Error message from MongoDB. Continuing."

        
        
        



if __name__ == "__main__":

    # search keyword ONE by ONE, gather 2000 tweets for each

    ##############################################
    ##############################################
    #   Stream parameters: just modify these, do NOT touch the rest
    ##############################################
    ##############################################

    client = pymongo.MongoClient()
    db = client.stream   # DATABASE_NAME
    collection = db.get_hashtags     # COLLECTION_NAME

    # search keyword ONE by ONE, gather 2000 tweets for each
    keyword = 'shisha'

    TAGS = keyword  
    TAGS_LIST = [keyword]

    ##############################################
    ##############################################
    ##############################################

    twitter_api = oauth_login()
    twitter_stream = twitter.TwitterStream(auth=twitter_api.auth)
    stream = twitter_stream.statuses.filter(track=TAGS, language='en')
    #stream = twitter_stream.statuses.sample(language='en') # stream a RANDOM sample
    print "Succesfully created a stream instance ... ... \n"
        #print "Filtering the public timeline for track="%s" \t \t " % (TAGS)

    for tweet_doc in stream:

        try:
            # 2 small modificatio to the tweet as it is gathered from API

            # 1. Add the tags of the search, to know from which search query the document has been obtained
            tweet_doc['keyword'] = TAGS_LIST  

            # 2. Substitue the defoult _id assigned by Mongo with the tweet id to prevent the same tweet to be inserted more than once
            tweet_doc['_id'] = tweet_doc["id"]
            del tweet_doc['id']

            save_to_mongo(tweet_doc, db, collection)

            print "\n %s \n" % tweet_doc['text']

            documents_in_collection = collection.find({"keyword": keyword}).count()

            if documents_in_collection >= 28000:

                print "Stremed 2000 tweets associated with keyword: \"%s\"" % keyword
                break
        
        except KeyError:
            print "KeyError, skipping tweet and continuing."
            continue
# Out:
# Succesfully connected to TwitterAPI ... ...
# Succesfully created a stream instance ... ...
#
#
#  Fantasia Herbal Shisha 50g - Hookah Flavors (ICE MINT)  https://t.co/TpirO2cAqx
#
#
#  355 increased shisha from 2500 to 3500.
#
# Just to be inhaling and blowing out smoke in this economy. Why I have car with 2 exhaust pipes?
#
#
#  Tolong setting arang shisha
# Tolong recoil vape
# Tolong gulung rokok
#
# But still tak isap. I just enjoy the ritual
#
#
#  The Perfect Setup for a true hookah enthousiast! I https://t.co/SZL7DWUqNQ #SHISHA https://t.co/06GC3PTdir
#
#
#  Come check out our great selection of Hookahs, Shisha,
# Hookah Pens &amp; Hookah Accessories.
# 101 E Big Bear Blvd, Big... https://t.co/TdZtWMwJLc
#
#
#  Shisha in Philippine  what a fuck is amazing https://t.co/k1QVGfeSVZ
#
#
#  😧😥💨💨 (at Sport Cafe n Shisha) — https://t.co/iX38wqiSiZ
#
#
#  Lmao are you mad.  https://t.co/DWE7Sl2ri6
#
#
#  We are open to the public today so come and join us tonight @MisPark_Dempsey shishavapes #shisha… https://t.co/n7X0yALUAi
#
#
#  RT @serenaxmaria: ID RATHER KILL MYSELF THAN DO SHISHA GROSS
#
#
#  Good ambience, dark, great home band, definitely wanna comeback… (w/ Viky &amp; ichsan at Chaplin's Cafe Bar Shisha) — https://t.co/RI6OxFZAAu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3b7c3daa889b> in <module>()
#      65         #print "Filtering the public timeline for track="%s" \t \t " % (TAGS)
#      66
# ---> 67     for tweet_doc in stream:
#      68
#      69         try:
#
# /usr/local/lib/python2.7/site-packages/twitter/stream.pyc in __iter__(self)
#     174         while True:
#     175             # Decode all the things:
# --> 176             data = sock_reader.read()
#     177             dechunked_data, end_of_stream, decode_error = chunk_decoder.decode(data)
#     178             unicode_data = utf8_decoder.decode(dechunked_data)
#
# /usr/local/lib/python2.7/site-packages/twitter/stream.pyc in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# KeyboardInterrupt:
